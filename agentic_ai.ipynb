# %%
# !pip install faiss-cpu numpy scikit-learn
# !pip install "tensorflow>=2.0.0"
# !pip install --upgrade tensorflow-hub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: faiss-cpu in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (1.13.2)
# Requirement already satisfied: numpy in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (1.8.0)
# Requirement already satisfied: packaging in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from faiss-cpu) (26.0)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from scikit-learn) (3.6.0)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: C:\Users\majji\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow>=2.0.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (3.4.0)
# Requirement already satisfied: packaging in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (2.32.5)
# Requirement already satisfied: setuptools in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (1.26.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow>=2.0.0) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0) (2025.8.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from astunparse>=1.6.0->tensorflow>=2.0.0) (0.46.3)
# Requirement already satisfied: rich in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from keras>=3.12.0->tensorflow>=2.0.0) (14.3.2)
# Requirement already satisfied: namex in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from keras>=3.12.0->tensorflow>=2.0.0) (0.1.0)
# Requirement already satisfied: optree in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from keras>=3.12.0->tensorflow>=2.0.0) (0.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from rich->keras>=3.12.0->tensorflow>=2.0.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from rich->keras>=3.12.0->tensorflow>=2.0.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow>=2.0.0) (0.1.2)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: C:\Users\majji\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-hub in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow-hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow-hub) (6.33.5)
# Requirement already satisfied: tf-keras>=2.14.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow-hub) (2.21.0)
# Requirement already satisfied: tensorflow<2.22,>=2.21 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (3.4.0)
# Requirement already satisfied: packaging in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (26.0)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (2.32.5)
# Requirement already satisfied: setuptools in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (3.13.2)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (2025.8.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from astunparse>=1.6.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (0.46.3)
# Requirement already satisfied: rich in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (14.3.2)
# Requirement already satisfied: namex in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (0.1.0)
# Requirement already satisfied: optree in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (0.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow-hub) (0.1.2)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: C:\Users\majji\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import faiss
import re
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from pprint import pprint

# Suppressing warnings
def warn(*args, **kwargs):
    pass

import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')
# Out:
# C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING:tensorflow:From C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from sklearn.datasets import fetch_20newsgroups
newsgroups_train = fetch_20newsgroups(subset='train')

# %%
pprint(list(newsgroups_train.target_names))
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
for i in range(3):
    print(f"Sample post {i+1}:\n")
    pprint(newsgroups_train.data[i])
    print("\n" + "-"*80 + "\n")
# Out:
# Sample post 1:
#
# ("From: lerxst@wam.umd.edu (where's my thing)\n"
#  'Subject: WHAT car is this!?\n'
#  'Nntp-Posting-Host: rac3.wam.umd.edu\n'
#  'Organization: University of Maryland, College Park\n'
#  'Lines: 15\n'
#  '\n'
#  ' I was wondering if anyone out there could enlighten me on this car I saw\n'
#  'the other day. It was a 2-door sports car, looked to be from the late 60s/\n'
#  'early 70s. It was called a Bricklin. The doors were really small. In '
#  'addition,\n'
#  'the front bumper was separate from the rest of the body. This is \n'
#  'all I know. If anyone can tellme a model name, engine specs, years\n'
#  'of production, where this car is made, history, or whatever info you\n'
#  'have on this funky looking car, please e-mail.\n'
#  '\n'
#  'Thanks,\n'
#  '- IL\n'
#  '   ---- brought to you by your neighborhood Lerxst ----\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n')
#
# --------------------------------------------------------------------------------
#
# Sample post 2:
#
# ('From: guykuo@carson.u.washington.edu (Guy Kuo)\n'
#  'Subject: SI Clock Poll - Final Call\n'
#  'Summary: Final call for SI clock reports\n'
#  'Keywords: SI,acceleration,clock,upgrade\n'
#  'Article-I.D.: shelley.1qvfo9INNc3s\n'
#  'Organization: University of Washington\n'
#  'Lines: 11\n'
#  'NNTP-Posting-Host: carson.u.washington.edu\n'
#  '\n'
#  'A fair number of brave souls who upgraded their SI clock oscillator have\n'
#  'shared their experiences for this poll. Please send a brief message '
#  'detailing\n'
#  'your experiences with the procedure. Top speed attained, CPU rated speed,\n'
#  'add on cards and adapters, heat sinks, hour of usage per day, floppy disk\n'
#  'functionality with 800 and 1.4 m floppies are especially requested.\n'
#  '\n'
#  'I will be summarizing in the next two days, so please add to the network\n'
#  "knowledge base if you have done the clock upgrade and haven't answered this\n"
#  'poll. Thanks.\n'
#  '\n'
#  'Guy Kuo <guykuo@u.washington.edu>\n')
#
# --------------------------------------------------------------------------------
#
# Sample post 3:
#
# ('From: twillis@ec.ecn.purdue.edu (Thomas E Willis)\n'
#  'Subject: PB questions...\n'
#  'Organization: Purdue University Engineering Computer Network\n'
#  'Distribution: usa\n'
#  'Lines: 36\n'
#  '\n'
#  'well folks, my mac plus finally gave up the ghost this weekend after\n'
#  "starting life as a 512k way back in 1985.  sooo, i'm in the market for a\n"
#  'new machine a bit sooner than i intended to be...\n'
#  '\n'
#  "i'm looking into picking up a powerbook 160 or maybe 180 and have a bunch\n"
#  'of questions that (hopefully) somebody can answer:\n'
#  '\n'
#  '* does anybody know any dirt on when the next round of powerbook\n'
#  "introductions are expected?  i'd heard the 185c was supposed to make an\n"
#  'appearence "this summer" but haven\'t heard anymore on it - and since i\n'
#  "don't have access to macleak, i was wondering if anybody out there had\n"
#  'more info...\n'
#  '\n'
#  '* has anybody heard rumors about price drops to the powerbook line like the\n'
#  "ones the duo's just went through recently?\n"
#  '\n'
#  "* what's the impression of the display on the 180?  i could probably swing\n"
#  "a 180 if i got the 80Mb disk rather than the 120, but i don't really have\n"
#  'a feel for how much "better" the display is (yea, it looks great in the\n'
#  'store, but is that all "wow" or is it really that good?).  could i solicit\n'
#  'some opinions of people who use the 160 and 180 day-to-day on if its worth\n'
#  'taking the disk size and money hit to get the active display?  (i realize\n'
#  "this is a real subjective question, but i've only played around with the\n"
#  'machines in a computer store breifly and figured the opinions of somebody\n'
#  'who actually uses the machine daily might prove helpful).\n'
#  '\n'
#  '* how well does hellcats perform?  ;)\n'
#  '\n'
#  "thanks a bunch in advance for any info - if you could email, i'll post a\n"
#  'summary (news reading time is at a premium with finals just around the\n'
#  'corner... :( )\n'
#  '--\n'
#  'Tom Willis  \\  twillis@ecn.purdue.edu    \\    Purdue Electrical '
#  'Engineering\n'
#  '---------------------------------------------------------------------------\n'
#  '"Convictions are more dangerous enemies of truth than lies."  - F. W.\n'
#  'Nietzsche\n')
#
# --------------------------------------------------------------------------------

# %%
newsgroups = fetch_20newsgroups(subset='all')
documents = newsgroups.data

# Basic preprocessing of text data
def preprocess_text(text):
    # Remove email headers
    text = re.sub(r'^From:.*\n?', '', text, flags=re.MULTILINE)
    # Remove email addresses
    text = re.sub(r'\S*@\S*\s?', '', text)
    # Remove punctuations and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    # Remove excess whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Preprocess each document
processed_documents = [preprocess_text(doc) for doc in documents]

# %%
sample_index = 0 


print("Original post:\n")
print(newsgroups_train.data[sample_index])
print("\n" + "-"*80 + "\n")

print("Preprocessed post:\n")
print(preprocess_text(newsgroups_train.data[sample_index]))
print("\n" + "-"*80 + "\n")
# Out:
# Original post:
#
# From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----
#
#
#
#
#
#
# --------------------------------------------------------------------------------
#
# Preprocessed post:
#
# subject what car is this nntppostinghost racwamumdedu organization university of maryland college park lines i was wondering if anyone out there could enlighten me on this car i saw the other day it was a door sports car looked to be from the late s early s it was called a bricklin the doors were really small in addition the front bumper was separate from the rest of the body this is all i know if anyone can tellme a model name engine specs years of production where this car is made history or whatever info you have on this funky looking car please email thanks il brought to you by your neighborhood lerxst
#
# --------------------------------------------------------------------------------

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

def embed_text(text):
    return embed(text).numpy()

X_use = np.vstack([embed_text([doc]) for doc in processed_documents])
# Out:
# WARNING:tensorflow:From C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\majji\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.

# %%
dimension = X_use.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(X_use)

# %%
def search(query_text, k=5):
    # Preprocess the query text
    preprocessed_query = preprocess_text(query_text)
    # Generate the query vector
    query_vector = embed_text([preprocessed_query])
    # Perform the search
    distances, indices = index.search(query_vector.astype('float32'), k)
    return distances, indices

# Example Query
query_text = "motorcycle"
distances, indices = search(query_text)

# Display the results
for i, idx in enumerate(indices[0]):
    # Ensure that the displayed document is the preprocessed one
    print(f"Rank {i+1}: (Distance: {distances[0][i]})\n{processed_documents[idx]}\n")
# Out:
# Rank 1: (Distance: 1.0367169380187988)
# subject first bike organization freshman mechanical engineering carnegie mellon pittsburgh pa lines nntppostinghost andrewcmuedu anyone i am a serious motorcycle enthusiast without a motorcycle and to put it bluntly it sucks i really would like some advice on what would be a good starter bike for me i do know one thing however i need to make my first bike a good one because buying a second any time soon is out of the question i am specifically interested in racing bikes cbr f gsxr i know that this may sound kind of crazy considering that ive never had a bike before but i am responsible a fast learner and in love please give me any advice that you think would help me in my search including places to look or even specific bikes that you want to sell me thanks jamie belliveau
#
# Rank 2: (Distance: 1.0392436981201172)
# subject first bike organization freshman mechanical engineering carnegie mellon pittsburgh pa lines nntppostinghost poandrewcmuedu anyone i am a serious motorcycle enthusiast without a motorcycle and to put it bluntly it sucks i really would like some advice on what would be a good starter bike for me i do know one thing however i need to make my first bike a good one because buying a second any time soon is out of the question i am specifically interested in racing bikes cbr f gsxr i know that this may sound kind of crazy considering that ive never had a bike before but i am responsible a fast learner and in love please give me any advice that you think would help me in my search including places to look or even specific bikes that you want to sell me thanks jamie belliveau
#
# Rank 3: (Distance: 1.051562786102295)
# subject re first bike organization microsoft corporation lines in recmotorcycles james leo belliveau writes i am a serious motorcycle enthusiast without a motorcycle and to put it bluntly it sucks i really would like some advice on what would be a good starter bike for me i do know one thing however i need to make my first bike a good one because buying a second any time soon is out of the question i am specifically interested in racing bikes cbr f gsxr i know that this may sound kind of crazy considering that ive never had a bike before but i am responsible a fast learner and in love responsible and in love i believe thats a contradiction in terms unless youre really brave read reckless a cc sport bike will go way faster than you dare for at least your first year of riding getting more than that really is overkill as youll never even want to use it the following bikes can be bought and repaired cheaply are easy for a novice to manage and are plenty high performance kawasaki ex honda vf interceptor suzuki gse the mph time of the ex at full throttle is way sooner than youre ready for it with something as small as a youd probably be wishing for more power pretty quickly unless its a tzr or rgv now im not saying that youre certain to kill yourself immediately with a f or a gsxr plenty of people have started riding on those bikes and done just fine what i am saying is that its a waste of money and a waste of perfectly good plastic when you drop the thing learning how to balance while stopping youll never get the throttle more than half open anyway so why spend the extra bucks chris
#
# Rank 4: (Distance: 1.052640438079834)
# subject re new to motorcycles organization hp sonoma county srsdmwtdmid xnewsreader tin version pl lines gregory humphreys wrote greg im very new to motorcycles havent even bought one yet i was in the same position about you how do you learn if youve never ridden i took a class put on by a group called the motorcycle safety foundation in california they might have something similar in washington try calling a motorcycle dealer in your area and asking its a good first start on how to ride a motorcycle correctly
#
# Rank 5: (Distance: 1.064742088317871)
# subject re first bike and wheelies organization st elizabeth hospital youngstown oh lines replyto john r daker nntppostinghost yfnysuedu in a previous article james leo belliveau says anyone i am a serious motorcycle enthusiast without a motorcycle and to put it bluntly it sucks i really would like some advice on what would be a good starter bike for me i do know one thing however i need to make my first bike a good one because buying a second any time soon is out of the question i am specifically interested in racing bikes cbr f gsxr i know that this may sound kind of crazy considering that ive never had a bike before but i am responsible a fast learner and in love please give me any advice that you think would help me in my search including places to look or even specific bikes that you want to sell me thanks the answer is obvious zx d dod darkman the significant problems we face cannot be solved at the same level of thinking we were at when we created them albert einstein the eternal champion

# %%
# Out:
# Rank 1: (Distance: 1.0367169380187988)
# From: James Leo Belliveau <jbc9+@andrew.cmu.edu>
# Subject: First Bike??
# Organization: Freshman, Mechanical Engineering, Carnegie Mellon, Pittsburgh, PA
# Lines: 17
# NNTP-Posting-Host: andrew.cmu.edu
#
#  Anyone,
#
#     I am a serious motorcycle enthusiast without a motorcycle, and to
# put it bluntly, it sucks.  I really would like some advice on what would
# be a good starter bike for me.  I do know one thing however, I need to
# make my first bike a good one, because buying a second any time soon is
# out of the question.  I am specifically interested in racing bikes, (CBR
# 600 F2, GSX-R 750).  I know that this may sound kind of crazy
# considering that I've never had a bike before, but I am responsible, a
# fast learner, and in love.  Please give me any advice that you think
# would help me in my search, including places to look or even specific
# bikes that you want to sell me.
#
#     Thanks  :-)
#
#     Jamie Belliveau (jbc9@andrew.cmu.edu)
#
#
#
# Rank 2: (Distance: 1.0392436981201172)
# From: James Leo Belliveau <jbc9+@andrew.cmu.edu>
# Subject: First Bike??
# Organization: Freshman, Mechanical Engineering, Carnegie Mellon, Pittsburgh, PA
# Lines: 17
# NNTP-Posting-Host: po2.andrew.cmu.edu
#
#  Anyone,
#
#     I am a serious motorcycle enthusiast without a motorcycle, and to
# put it bluntly, it sucks.  I really would like some advice on what would
# be a good starter bike for me.  I do know one thing however, I need to
# make my first bike a good one, because buying a second any time soon is
# out of the question.  I am specifically interested in racing bikes, (CBR
# 600 F2, GSX-R 750).  I know that this may sound kind of crazy
# considering that I've never had a bike before, but I am responsible, a
# fast learner, and in love.  Please give me any advice that you think
# would help me in my search, including places to look or even specific
# bikes that you want to sell me.
#
#     Thanks  :-)
#
#     Jamie Belliveau (jbc9@andrew.cmu.edu)
#
#
#
# Rank 3: (Distance: 1.051562786102295)
# From: chrispi@microsoft.com (Chris Pirih)
# Subject: Re: First Bike??
# Organization: Microsoft Corporation
# Lines: 39
#
# In rec.motorcycles James Leo Belliveau <jbc9+@andrew.cmu.edu> writes:
# ;    I am a serious motorcycle enthusiast without a motorcycle, and to
# ;put it bluntly, it sucks.  I really would like some advice on what would
# ;be a good starter bike for me.  I do know one thing however, I need to
# ;make my first bike a good one, because buying a second any time soon is
# ;out of the question.  I am specifically interested in racing bikes, (CBR
# ;600 F2, GSX-R 750).  I know that this may sound kind of crazy
# ;considering that I've never had a bike before, but I am responsible, a
# ;fast learner, and in love.
#
# Responsible and in love?  I believe that's a contradiction
# in terms.
#
# Unless you're really brave (read: "reckless") a 500cc sport
# bike will go way faster than you dare for at least your first
# year of riding.  Getting more than that really is overkill,
# as you'll never even want to use it.  The following bikes
# can be bought (and repaired!) cheaply, are easy for a novice
# to manage, and are plenty high performance:
#     Kawasaki EX-500
#     Honda VF-500 "Interceptor"
#     Suzuki GS-550E
#
# The 0-100mph time of the EX-500 at full throttle is "way
# sooner than you're ready for it".  :-)  With something
# as small as a 250, you'd probably be wishing for more
# power pretty quickly (unless it's a TZR or RGV :).
#
# Now, I'm not saying that you're 100% certain to kill
# yourself immediately with a 600f2 or a GSXR-750.  Plenty
# of people have started riding on those bikes and done
# just fine.  What I am saying is that it's a waste of
# money, and a waste of perfectly good plastic when you
# drop the thing learning how to balance while stopping.
# You'll never get the throttle more than half open
# anyway, so why spend the extra 2000 bucks?
#
# ---
# chris
#
#
# Rank 4: (Distance: 1.052640438079834)
# From: blaisec@sr.hp.com (Blaise Cirelli)
# Subject: Re: New to Motorcycles...
# Organization: HP Sonoma County (SRSD/MWTD/MID)
# X-Newsreader: TIN [version 1.1 PL8.8]
# Lines: 15
#
# Gregory Humphreys (gregh@niagara.dcrt.nih.gov) wrote:
#
#
#
# Greg,
#
# I'm very new to motorcycles. Haven't even bought one yet. I was in the same
# position about you. How do you learn if you've never ridden.
#
# I took a class put on by a group called the Motorcycle Safety Foundation
# in California. They might have something similar in Washington.
#
# Try calling a motorcycle dealer in your area and asking. It's a good first
# start on how to ride a motorcycle correctly.
#
#
#
# Rank 5: (Distance: 1.064742088317871)
# From: ak296@yfn.ysu.edu (John R. Daker)
# Subject: Re: First Bike?? and Wheelies
# Organization: St. Elizabeth Hospital, Youngstown, OH
# Lines: 24
# Reply-To: ak296@yfn.ysu.edu (John R. Daker)
# NNTP-Posting-Host: yfn.ysu.edu
#
#
# In a previous article, jbc9+@andrew.cmu.edu (James Leo Belliveau) says:
#
# > Anyone,
# >
# >    I am a serious motorcycle enthusiast without a motorcycle, and to
# >put it bluntly, it sucks.  I really would like some advice on what would
# >be a good starter bike for me.  I do know one thing however, I need to
# >make my first bike a good one, because buying a second any time soon is
# >out of the question.  I am specifically interested in racing bikes, (CBR
# >600 F2, GSX-R 750).  I know that this may sound kind of crazy
# >considering that I've never had a bike before, but I am responsible, a
# >fast learner, and in love.  Please give me any advice that you think
# >would help me in my search, including places to look or even specific
# >bikes that you want to sell me.
# >
# >    Thanks  :-)
#
# The answer is obvious: ZX-11 D.
# --
# DoD #650<----------------------------------------------------------->DarkMan
#    The significant problems we face cannot be solved at the same level of
#       thinking we were at when we created them.   - Albert Einstein
#          ___________________The Eternal Champion_________________
